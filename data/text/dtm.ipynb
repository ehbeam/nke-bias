# %% [markdown]
# # Load the lexicons

# %%
import pandas as pd
import preproc

# %%
ontol = pd.read_csv("../lexicon/lists_data-driven_lr.csv", index_col=None)
ontol.head()
# Out:
#    ORDER  CLUSTER  DOMAIN               TOKEN         R   ROC_AUC
# 0      1        6  MEMORY              memory  0.199004  0.655879
# 1      1        6  MEMORY     episodic_memory  0.174621  0.655879
# 2      1        6  MEMORY  declarative_memory  0.172933  0.655879
# 3      1        6  MEMORY  recognition_memory  0.162350  0.655879
# 4      1        6  MEMORY         remembering  0.157813  0.655879

# %%
lexicon_psyc = sorted(list(set(ontol["TOKEN"])))
len(lexicon_psyc)
# Out:
# 90

# %%
anat = pd.read_csv("../lexicon/lexicon_brain.csv", index_col=None)
anat.head()
# Out:
#   HARVARD_OXFORD                    TERMS          SOURCE     TYPE
# 0      accumbens                accumbens  Harvard-Oxford     term
# 1      accumbens                      acb      NeuroNames  acronym
# 2      accumbens        nucleus accumbens      NeuroNames     term
# 3      accumbens        accumbens nucleus      NeuroNames     term
# 4      accumbens  nucleus accumbens septi      NeuroNames     term

# %%
# From "synonyms" notebook
struct2synonyms = { 
                    'amygdala': ['amygdalar'],
                    'hippocampus': ['hippocampal', 'hippocampal_formation'],
                    'cerebellum': ['cerebellar'],
                    'thalamus': ['thalamic'],
                    'middle_frontal_gyrus': ['mfg'],
                    'caudate': ['caudate_nucleus', 'caudate_head', 'caudate_nucleus_putamen'],
                    'precentral_gyrus': ['precentral'],
                    'superior_frontal_gyrus': ['sfg'],
                    'postcentral_gyrus': ['postcentral'],
                    'lingual_gyrus': ['lingual'],
                    'superior_parietal_lobule': ['spl', 'superior_parietal_gyrus'],
                    'brainstem': ['brain_stem'],
                    'insular_cortex': ['insula', 'insular', 'insular_region'],
                    'frontal_pole': ['frontopolar', 'frontal_operculum'],
                    'heschls_gyrus': ['heschl', 'hg', 'heschls'],
                    'planum_temporale': ['planum'],
                    'supplementary_motor_cortex': ['supplementary_motor_area', 'sma'],
                    'paracingulate_gyrus': ['paracingulate', 'paracentral'],
                    'planum_polare': ['planum'],
                    'subcallosal_cortex': ['subcallosal'],
                    'frontal_medial_cortex': ['fmc'],
                    'precuneous_cortex': ['precuneous'],
                    'frontal_operculum_cortex': ['frontal_operculumanterior']
                  }

# %%
lexicon_anat = []
for struct, struct_terms in struct2synonyms.items():
    lexicon_anat += struct_terms
len(lexicon_anat)
# Out:
# 34

# %%
for term in anat["TERMS"]:
    term = preproc.preprocess_text(term).replace(" ", "_")
    lexicon_anat.append(term)
lexicon_anat = sorted(list(set(lexicon_anat)))
len(lexicon_anat)
# Out:
# 281

# %% [markdown]
# # Load the corpus PMIDs

# %%
df = pd.read_csv("../metadata/metadata.csv", encoding="latin-1")
df.head()
# Out:
#       PMID               DOI                KEY    SOURCE  \
# 0  1402966               NaN    Dolan R J, 1992  BrainMap
# 1  1410086               NaN    Bench C J, 1992  BrainMap
# 2  1448149  10.1038/360339a0  Zatorre R J, 1992  BrainMap
# 3  1486459               NaN  Demonet J F, 1992  BrainMap
# 4  1486460               NaN     Howard D, 1992  BrainMap
#
#                                              AUTHORS  YEAR MONTH  \
# 0  Dolan R J|Bench C J|Brown R G|Scott L C|Fristo...  1992   Sep
# 1  Bench C J|Friston K J|Brown R G|Scott L C|Frac...  1992   Aug
# 2       Zatorre R J|Jones-Gotman M|Evans A C|Meyer E  1992   Nov
# 3  Demonet J F|Chollet F|Ramsay S|Cardebat D|Nesp...  1992   Dec
# 4  Howard D|Patterson K|Wise R J S|Brown W D|Fris...  1992   Dec
#
#                                           JOURNAL  \
# 0  JOURNAL OF NEUROLOGY NEUROSURGERY & PSYCHIATRY
# 1                          PSYCHOLOGICAL MEDICINE
# 2                                          NATURE
# 3                                           BRAIN
# 4                                           BRAIN
#
#                                                TITLE      PAGES  ...  \
# 0  Regional cerebral blood flow abnormalities in ...    768-773  ...
# 1  The anatomy of melancholia - focal abnormaliti...    607-615  ...
# 2  Functional localization and lateralization of ...    339-340  ...
# 3  The anatomy of phonological and semantic proce...  1753-1768  ...
# 4  The cortical localization of the lexicons: Pos...  1769-1782  ...
#
#   NUM_COORDINATES                                    MNI_COORDINATES  \
# 0             7.0  -7.66,51.87,-8.33;-5.51,56.46,-4.28;-5.48,58.9...
# 1            10.0  -13.68,29.54,33.76;-15.76,23.53,38.75;-39.5,38...
# 2             6.0  -21.56,5.58,-27.71;22.3,6.36,-21.58;18.98,41.4...
# 3            30.0  -58.78,13.84,-0.09;-56.57,-13.98,-2.25;-56.6,-...
# 4            14.0  -52.17,-30.19,7.98;56.78,-16.85,5.61;-52.1,-49...
#
#    BRAINMAP_ID                                  BEHAVIORAL_DOMAIN  \
# 0    6030020.0                     ['Action.Rest', 'Action.Rest']
# 1    6030018.0      ['Action.Rest', 'Action.Rest', 'Action.Rest']
# 2    8110311.0                           ['Perception.Olfaction']
# 3      30434.0  ['Cognition.Language.Phonology', 'Cognition.La...
# 4    4020008.0  ['Perception.Audition', 'Cognition.Language.Sp...
#
#                                           EXPERIMENT  \
# 0  ['Unimpaired > Impaired', 'Impaired > Unimpair...
# 1  ['Normals > Depressed', 'Unimpaired > Impaired...
# 2                              ['Odor vs. Odorless']
# 3  ['Phonemes - Tones', 'Words - Tones', 'Words -...
# 4  ['Hear and Say - See and Say', 'Word Reading v...
#
#                                          DESCRIPTION IMPACT_FACTOR_2018  \
# 0  Patients with depression who were cognitively ...              8.327
# 1  Patients with depression and normal subjects u...              5.641
# 2  Subjects underwent 2 conditions in which they ...             43.070
# 3  Subjects underwent 3 conditions in which they ...             11.814
# 4  Subjects underwent 4 conditions. Condition 1: ...             11.814
#
#   CITATIONS  CITATIONS_PER_YEAR  N_SUBJECTS
# 0        21            0.750000        10.0
# 1        94            3.357143        10.0
# 2        84            3.000000        11.0
# 3       201            7.178571         9.0
# 4        75            2.678571        12.0
#
# [5 rows x 22 columns]

# %%
pmids = list(df["PMID"].astype(int))
len(pmids)
# Out:
# 18155

# %% [markdown]
# # Fit document-term matrices

# %% [markdown]
# ## Corpus of full texts

# %%
records = [open("fulltexts/{}.txt".format(pmid), "r").read() for pmid in pmids]

# %%
dtm = preproc.fit_dtm(records, pmids, lexicon_psyc, "fulltexts_psyc")
dtm.sum()
# Out:
# action                      80133
# anticipation                15714
# arousal                     17789
# articulation                 2806
# attention                   84622
# audition                     1041
# auditory_perception           760
# autobiographical_memory      5413
# cognitive                   96273
# cognitive_control           23911
# cognitive_process            9113
# context                     44732
# covert                       6007
# decision                    36045
# decision_making             10841
# declarative_memory           2021
# emotion                     68157
# emotional_memory             2190
# encoding                    60711
# encoding_task                2188
# episodic_memory             11975
# episodic_simulation           400
# error_detection              2479
# execution                   15072
# face                       128325
# face_perception              4451
# facial_expression           18354
# familiarity                 14862
# fear                        25387
# goal                        18420
#                             ...
# rehearsal                    3795
# remembering                  5106
# response_selection           4785
# retrieval                   53029
# reward                      65737
# reward_anticipation          3442
# reward_learning               868
# reward_processing            5097
# salience                    15425
# semantic_processing          8468
# source_memory                3822
# spatial_attention            7297
# speech                      46934
# speech_perception            4844
# speech_processing            2428
# speech_production            4840
# strategy                    28034
# syllable                    10002
# syntax                       2953
# tone                        15118
# valence                     25882
# vision                      14046
# visual_angle                 3018
# visual_attention             5320
# visual_imagery               2985
# visual_object                2253
# visual_perception            2759
# voice_perception              336
# word                       149807
# working_memory              53514
# Length: 90, dtype: int64

# %%
dtm = preproc.fit_dtm(records, pmids, lexicon_anat, "fulltexts_anat")
dtm.sum()
# Out:
# acb                                                81
# accumbens                                         715
# accumbens_nucleus                                  30
# acgg                                                6
# amg                                               594
# amygdala                                       116973
# amygdalar                                        2324
# amygdaloid_body                                    19
# amygdaloid_nuclear_complex                          2
# amygdaloid_nucleus                                130
# ang                                               748
# anterior_central_gyrus                              3
# anterior_cingulate                              52242
# anterior_cingulate_gyrus                         5596
# anterior_inferior_temporal_gyrus                  126
# anterior_middle_temporal_gyrus                    333
# anterior_mtg                                      196
# anterior_nucleus                                  162
# anterior_parahippocampal_gyrus                    201
# anterior_smg                                       60
# anterior_stg                                      498
# anterior_superior_temporal_gyrus                  566
# anterior_supramarginal_gyrus                        0
# anterior_temporal_fusiform_cortex                  12
# aphg                                               75
# archistriatum                                       2
# area_1                                            891
# area_10                                          1409
# area_17                                           671
# area_2                                           1148
#                                                 ...
# superior_parietal_gyrus                          1394
# superior_parietal_lobule                        11311
# superior_temporal_gyrus_anterior_division          20
# superior_temporal_gyrus_posterior_division         33
# supplementary_motor_area                        12955
# supplementary_motor_cortex                       1263
# supracalcarine_cortex                              77
# supramarginal_gyrus_anterior_division               0
# supramarginal_gyrus_posterior_division              0
# temporal_fusiform_cortex_anterior_division          9
# temporal_fusiform_cortex_posterior_division        19
# temporal_occipital_fusiform_cortex                194
# temporal_plane                                    401
# temporal_pole                                    9718
# temporooccipital_inferior_temporal_gyrus            4
# temporooccipital_middle_temporal_gyrus             11
# temporooccipital_mtg                                6
# th                                               3029
# thalamencephalon                                    0
# thalamic                                         8960
# thalamus                                        42986
# thalamus_dorsalis                                   0
# tmp                                                16
# transverse_temporal_gyrus                        1021
# triangular_part_inferior_frontal_gyrus             97
# truncus_cerebri                                     0
# ventral_anterior_nucleus                          115
# ventral_lateral_nucleus                           204
# ventral_posterior_lateral_nucleus                  60
# ventral_posterior_medial_nucleus                   30
# Length: 281, dtype: int64

# %% [markdown]
# ## Corpus of abstracts

# %%
records = [open("abstracts/{}.txt".format(pmid), "r").read() for pmid in pmids]

# %%
dtm = preproc.fit_dtm(records, pmids, lexicon_psyc, "abstracts_psyc")
dtm.sum()
# Out:
# action                     3843
# anticipation                795
# arousal                     628
# articulation                 86
# attention                  3429
# audition                     40
# auditory_perception          32
# autobiographical_memory     223
# cognitive                  5647
# cognitive_control          1370
# cognitive_process           407
# context                    2001
# covert                      269
# decision                   1578
# decision_making             563
# declarative_memory           95
# emotion                    2585
# emotional_memory             97
# encoding                   2838
# encoding_task                73
# episodic_memory             586
# episodic_simulation          16
# error_detection              70
# execution                   694
# face                       5428
# face_perception             138
# facial_expression           768
# familiarity                 502
# fear                       1108
# goal                        847
#                            ...
# rehearsal                   120
# remembering                 173
# response_selection          189
# retrieval                  2396
# reward                     3328
# reward_anticipation         245
# reward_learning              36
# reward_processing           439
# salience                    834
# semantic_processing         320
# source_memory               144
# spatial_attention           264
# speech                     2039
# speech_perception           229
# speech_processing            92
# speech_production           209
# strategy                   1110
# syllable                    292
# syntax                      101
# tone                        521
# valence                     836
# vision                      271
# visual_angle                  5
# visual_attention            157
# visual_imagery              100
# visual_object                88
# visual_perception           131
# voice_perception             28
# word                       4871
# working_memory             2343
# Length: 90, dtype: int64

# %%
dtm = preproc.fit_dtm(records, pmids, lexicon_anat, "abstracts_anat")
dtm.sum()
# Out:
# acb                                               0
# accumbens                                        25
# accumbens_nucleus                                 0
# acgg                                              0
# amg                                              12
# amygdala                                       5274
# amygdalar                                       101
# amygdaloid_body                                   0
# amygdaloid_nuclear_complex                        0
# amygdaloid_nucleus                                0
# ang                                              12
# anterior_central_gyrus                            0
# anterior_cingulate                             3052
# anterior_cingulate_gyrus                        216
# anterior_inferior_temporal_gyrus                  4
# anterior_middle_temporal_gyrus                   13
# anterior_mtg                                      5
# anterior_nucleus                                  3
# anterior_parahippocampal_gyrus                    9
# anterior_smg                                      0
# anterior_stg                                     11
# anterior_superior_temporal_gyrus                 31
# anterior_supramarginal_gyrus                      9
# anterior_temporal_fusiform_cortex                 0
# aphg                                              0
# archistriatum                                     0
# area_1                                           16
# area_10                                          37
# area_17                                           6
# area_2                                           32
#                                                ...
# superior_parietal_gyrus                          24
# superior_parietal_lobule                        356
# superior_temporal_gyrus_anterior_division         0
# superior_temporal_gyrus_posterior_division        0
# supplementary_motor_area                        692
# supplementary_motor_cortex                       56
# supracalcarine_cortex                             2
# supramarginal_gyrus_anterior_division             0
# supramarginal_gyrus_posterior_division            0
# temporal_fusiform_cortex_anterior_division        0
# temporal_fusiform_cortex_posterior_division       0
# temporal_occipital_fusiform_cortex                0
# temporal_plane                                   11
# temporal_pole                                   304
# temporooccipital_inferior_temporal_gyrus          0
# temporooccipital_middle_temporal_gyrus            1
# temporooccipital_mtg                              0
# th                                               31
# thalamencephalon                                  0
# thalamic                                        358
# thalamus                                       1772
# thalamus_dorsalis                                 0
# tmp                                               2
# transverse_temporal_gyrus                        10
# triangular_part_inferior_frontal_gyrus            4
# truncus_cerebri                                   0
# ventral_anterior_nucleus                          2
# ventral_lateral_nucleus                           5
# ventral_posterior_lateral_nucleus                 0
# ventral_posterior_medial_nucleus                  0
# Length: 281, dtype: int64

# %% [markdown]
# # Sum across anatomical synonyms

# %%
lexicon_harvox = sorted(list(set(anat["HARVARD_OXFORD"])))
len(lexicon_harvox)
# Out:
# 57

# %%
def sum_synonyms(dtm, lexicon):
    dtm_sums = pd.DataFrame(index=dtm.index)
    for struct in lexicon:
        synonyms = [term for term in anat.loc[anat["HARVARD_OXFORD"] == struct, "TERMS"]] # Synonyms from NeuroNames
        if struct in struct2synonyms.keys():
            synonyms += struct2synonyms[struct]
        synonyms = [preproc.preprocess_text(term).replace(" ", "_") for term in synonyms]
        synonyms = [term for term in synonyms if term in dtm.columns]
        dtm_sums[struct] = dtm[synonyms].sum(axis=1)
    return dtm_sums

# %% [markdown]
# ## Corpus of full texts

# %%
dtm = pd.read_csv("dtm_fulltexts_anat.csv.gz", index_col=0, header=0)
dtm_sums = sum_synonyms(dtm, lexicon_harvox)
dtm_sums.to_csv("dtm_fulltexts_anat-syns.csv.gz")
dtm_sums.head()
# Out:
#          accumbens  amygdala  angular_gyrus  brainstem  caudate  \
# 1402966          0         1              0          0        3
# 1410086          0         2              0          2        1
# 1448149          0         0              0          0        0
# 1486459          0         0              0          0        2
# 1486460          0         0              0          0        5
#
#          central_opercular_cortex  cerebellum  \
# 1402966                         0          26
# 1410086                         0          13
# 1448149                         0           0
# 1486459                         0           0
# 1486460                         0           0
#
#          cingulate_gyrus_anterior_division  \
# 1402966                                  3
# 1410086                                 11
# 1448149                                  0
# 1486459                                  2
# 1486460                                  4
#
#          cingulate_gyrus_posterior_division  cuneal_cortex  ...  \
# 1402966                                   0              0  ...
# 1410086                                   5              0  ...
# 1448149                                   0              0  ...
# 1486459                                   5              0  ...
# 1486460                                   0              2  ...
#
#          superior_temporal_gyrus_posterior_division  \
# 1402966                                           0
# 1410086                                           0
# 1448149                                           0
# 1486459                                           0
# 1486460                                           1
#
#          supplementary_motor_cortex  supracalcarine_cortex  \
# 1402966                           0                      0
# 1410086                           0                      0
# 1448149                           0                      0
# 1486459                           2                      0
# 1486460                           0                      0
#
#          supramarginal_gyrus_anterior_division  \
# 1402966                                      0
# 1410086                                      0
# 1448149                                      0
# 1486459                                      0
# 1486460                                      0
#
#          supramarginal_gyrus_posterior_division  \
# 1402966                                       0
# 1410086                                       0
# 1448149                                       0
# 1486459                                       0
# 1486460                                       0
#
#          temporal_fusiform_cortex_anterior_division  \
# 1402966                                           0
# 1410086                                           0
# 1448149                                           0
# 1486459                                           0
# 1486460                                           0
#
#          temporal_fusiform_cortex_posterior_division  \
# 1402966                                            0
# 1410086                                            0
# 1448149                                            0
# 1486459                                            0
# 1486460                                            0
#
#          temporal_occipital_fusiform_cortex  temporal_pole  thalamus
# 1402966                                   0              0         0
# 1410086                                   0              0         0
# 1448149                                   0              0         0
# 1486459                                   0              0         0
# 1486460                                   0              0         0
#
# [5 rows x 57 columns]

# %%
dtm_sums.sum()
# Out:
# accumbens                                          8989
# amygdala                                         120420
# angular_gyrus                                       799
# brainstem                                         30074
# caudate                                           49447
# central_opercular_cortex                           4629
# cerebellum                                        91889
# cingulate_gyrus_anterior_division                 60535
# cingulate_gyrus_posterior_division                26127
# cuneal_cortex                                     12848
# frontal_medial_cortex                             12001
# frontal_operculum_cortex                           3409
# frontal_orbital_cortex                             5202
# frontal_pole                                      16757
# heschls_gyrus                                     12754
# hippocampus                                       91985
# inferior_frontal_gyrus_pars_opercularis            7221
# inferior_frontal_gyrus_pars_triangularis           5110
# inferior_temporal_gyrus_anterior_division           146
# inferior_temporal_gyrus_posterior_division          296
# inferior_temporal_gyrus_temporooccipital_part        33
# insular_cortex                                   194711
# intracalcarine_cortex                              9894
# lateral_occipital_cortex_inferior_division          456
# lateral_occipital_cortex_superior_division         2795
# lingual_gyrus                                     15928
# middle_frontal_gyrus                              58837
# middle_temporal_gyrus_anterior_division             544
# middle_temporal_gyrus_posterior_division           1954
# middle_temporal_gyrus_temporooccipital_part          75
# occipital_fusiform_gyrus                            677
# occipital_pole                                     3551
# pallidum                                           8422
# paracingulate_gyrus                                5586
# parahippocampal_gyrus_anterior_division             674
# parahippocampal_gyrus_posterior_division            805
# parietal_operculum_cortex                          2681
# planum_polare                                       729
# planum_temporale                                   3499
# postcentral_gyrus                                 25623
# precentral_gyrus                                  37098
# precuneous_cortex                                 45145
# putamen                                           30528
# subcallosal_cortex                                 1718
# superior_frontal_gyrus                            36090
# superior_parietal_lobule                          33983
# superior_temporal_gyrus_anterior_division          1084
# superior_temporal_gyrus_posterior_division         2200
# supplementary_motor_cortex                        40204
# supracalcarine_cortex                                77
# supramarginal_gyrus_anterior_division                60
# supramarginal_gyrus_posterior_division               29
# temporal_fusiform_cortex_anterior_division           21
# temporal_fusiform_cortex_posterior_division          49
# temporal_occipital_fusiform_cortex                  194
# temporal_pole                                     10894
# thalamus                                          59499
# dtype: int64

# %% [markdown]
# ## Corpus of abstracts

# %%
dtm = pd.read_csv("dtm_abstracts_anat.csv.gz", index_col=0, header=0)
dtm_sums = sum_synonyms(dtm, lexicon_harvox)
dtm_sums.to_csv("dtm_abstracts_anat-syns.csv.gz")

# %%
dtm_sums.sum()
# Out:
# accumbens                                         386
# amygdala                                         5389
# angular_gyrus                                      12
# brainstem                                        1402
# caudate                                          1748
# central_opercular_cortex                          111
# cerebellum                                       3710
# cingulate_gyrus_anterior_division                3296
# cingulate_gyrus_posterior_division               1331
# cuneal_cortex                                     254
# frontal_medial_cortex                             281
# frontal_operculum_cortex                          120
# frontal_orbital_cortex                             91
# frontal_pole                                      426
# heschls_gyrus                                     352
# hippocampus                                      3934
# inferior_frontal_gyrus_pars_opercularis           173
# inferior_frontal_gyrus_pars_triangularis          106
# inferior_temporal_gyrus_anterior_division           4
# inferior_temporal_gyrus_posterior_division         12
# inferior_temporal_gyrus_temporooccipital_part       0
# insular_cortex                                   8777
# intracalcarine_cortex                             237
# lateral_occipital_cortex_inferior_division          5
# lateral_occipital_cortex_superior_division         26
# lingual_gyrus                                     367
# middle_frontal_gyrus                             1167
# middle_temporal_gyrus_anterior_division            18
# middle_temporal_gyrus_posterior_division           90
# middle_temporal_gyrus_temporooccipital_part         1
# occipital_fusiform_gyrus                           14
# occipital_pole                                     36
# pallidum                                          230
# paracingulate_gyrus                               146
# parahippocampal_gyrus_anterior_division            14
# parahippocampal_gyrus_posterior_division           25
# parietal_operculum_cortex                          90
# planum_polare                                      24
# planum_temporale                                  154
# postcentral_gyrus                                 508
# precentral_gyrus                                  665
# precuneous_cortex                                1615
# putamen                                          1144
# subcallosal_cortex                                 40
# superior_frontal_gyrus                            671
# superior_parietal_lobule                          772
# superior_temporal_gyrus_anterior_division          42
# superior_temporal_gyrus_posterior_division         84
# supplementary_motor_cortex                       1380
# supracalcarine_cortex                               2
# supramarginal_gyrus_anterior_division               9
# supramarginal_gyrus_posterior_division              3
# temporal_fusiform_cortex_anterior_division          0
# temporal_fusiform_cortex_posterior_division         0
# temporal_occipital_fusiform_cortex                  0
# temporal_pole                                     324
# thalamus                                         2310
# dtype: int64
